# %%
print("hello world")
# Out:
# hello world

# %%
name = (input("enter your name"))
print(name)
# Out:
# bibhu

# %%
number = float(input("enter number"))
if number > 0:
   print("number is positive" )

elif number < 0:
   print("number is negative")

else:
    print("number is 0")
# Out:
# number is positive

# %%
num1 = float(input("enter num1"))
num2 = float(input("enter num2"))
num3 = float(input("enter num3"))

if num1 > num2 and num1 > num3:
     largest = num1

elif num2 > num1 and num2 > num3:
     largest = num2

else:
     largest = num3

     print("the largest num is",largest)
# Out:
# the largest num is 79.0

# %%
num = int(input("enter a num"))

factorial = 1

for i in range (1,num+1):
    factorial = factorial*i

    print("factorial is",factorial)
# Out:
# factorial is 1
# factorial is 2
# factorial is 6
# factorial is 24
# factorial is 120

# %%
a = 2
b = 2.1
c = 'bibhu'
d = True

print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# 2 <class 'int'>
# 2.1 <class 'float'>
# bibhu <class 'str'>
# True <class 'bool'>

# %%
a = 10
b = 20 

print("before swipping",a,b)

a,b = b,a

print("after swapping",a,b)
# Out:
# before swipping 10 20
# after swapping 20 10

# %%
celsius = float(input("enter temp in celcious"))
fahernheit = (celsius * 9/5) + 32

print("fahernheit is", fahernheit)
# Out:
# fahernheit is 122.0

# %%
value = int(input("enter value"))
if isinstance(value,int):
    print("it is an integer")

else:
    print("it is not an integer")
# Out:
# it is an integer

# %%
a = int(input("enter 1st number"))
b = int(input("enter 2nd number"))

add = a+b 
sub = a-b
mul = a*b
div = a/b
print("add",add)
print("sub",sub)
print("mul",mul)
print("div",div)
# Out:
# add 11
# sub 5
# mul 24
# div 2.6666666666666665

# %%
a = 20
b = 10

print("equal", a==b)
print("not equal to",a!=b)
print("greater than", a>b)
print("less than",a<b)
# Out:
# equal False
# not equal to True
# greater than True
# less than False

# %%
a = True
b = False

print("AND:", a and b)
print("OR:", a or b)
print("NOT:", not a)
# Out:
# AND: False
# OR: True
# NOT: False

# %%
n = int(input("enter a number"))
if n > 0:
    square= n**2

    print("square is",square)
# Out:
# square is 1877835556

# %%
n = int(input("enter a number"))


if    n % 2 == 0:
    print("number is even")

else:
    print("number is odd")
# Out:
# number is even

# %%
n = 10
sum = 0
count = 1

while count <= n:
    sum = sum+count
    count= count + 1

    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
year = int(input("Enter year: "))

if year % 400 == 0:
    print("Year is a leap year")

elif year % 4 == 0 and year % 100 != 0:
    print("Year is a leap year")

else:
    print("Year is not a leap year")
# Out:
# Year is a leap year

# %%
text = input("enter a string")
reversed_text = text[::-1]

print("reversed_text",reversed_text)
# Out:
# reversed_text uhbib

# %%
text = input("enter text")

if text == text[::-1]:
    print("ir is a palindrome")

else:
    print("'it is not a palindrome")
# Out:
# 'it is not a palindrome
